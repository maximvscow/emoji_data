# %%
import pandas as pd

# %%
pd.read_csv('df2.csv')
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  {'count': 15, 'items': [{'id': 4292332, 'from_...
# 1           1  {'count': 2, 'items': [{'id': 17284193, 'from_...
# 2           2  {'count': 2, 'items': [{'id': 8450704, 'from_i...
# 3           3  {'count': 13273, 'items': [{'id': 19771482, 'f...
#
#                                                    1  \
# 0  {'count': 24, 'items': [{'id': 4292315, 'from_...
# 1  {'count': 66, 'items': [{'id': 17284020, 'from...
# 2  {'count': 40, 'items': [{'id': 8450673, 'from_...
# 3  {'count': 43, 'items': [{'id': 24787797, 'from...
#
#                                                    2  \
# 0  {'count': 26, 'items': [{'id': 4292282, 'from_...
# 1  {'count': 100, 'items': [{'id': 17283837, 'fro...
# 2  {'count': 15, 'items': [{'id': 8450655, 'from_...
# 3  {'count': 113, 'items': [{'id': 24787150, 'fro...
#
#                                                    3  \
# ...
